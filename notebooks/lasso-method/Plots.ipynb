# %%
import sys 
import glob 
import matplotlib.pyplot as plt
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt 
import matplotlib.ticker as ticker


sys.path.append('../../code/')
sys.path.append('../../analysis/')
import utils
from utils import read_pickle_file

from analysis_utils import get_adjacency
from all_stimuli_plots import *

from all_stimuli_plots import plot_heatmaps_with_all_stimuli
from calculate_pvalues import correct_pvalues

base_dir = '/media/yido/additional/research/neuroscience'

# %% [markdown]
# ## Plots with all stimuli together

# %%
# # # stimulus 15  
data_9 = read_plot_data('/Users/yido/Code/neuroscience/', 
                 '/Users/yido/Code/neuroscience/output_stimuli_9/DI_values/pre_spk_times_0.2/9/500_1500/lasso/*.pkl', 
                '/Users/yido/Code/neuroscience/output_stimuli_9/DI_values/post_9_spk_times_0.2/9/500_1500/lasso/*.pkl',) 
data_15 = read_plot_data('/Users/yido/Code/neuroscience/', 
                        '/Users/yido/Code/neuroscience/output_stimuli_15/DI_values/pre_spk_times_0.2/15/500_1500/lasso/*.pkl',
                        '/Users/yido/Code/neuroscience/output_stimuli_15/DI_values/post_15_spk_times_0.2/15/500_1500/lasso/*.pkl')

utils.pickle_object(data_9, '/Users/yido/Code/neuroscience/output_stimuli_9/stimulus_9_500_1500_0.2_areal_plots_data.pkl')
utils.pickle_object(data_15, '/Users/yido/Code/neuroscience/output_stimuli_15/stimulus_15_500_1500_0.2_areal_plots_data.pkl')
# Out:
# Working with 0 units for stimulus 0 with min spiking rate of 0.0
# Issues summary {'negative_di': 0, 'n_areas': 0, 'zero_contrib': 0, 'low_firing_rates': 0}
# Working with 0 units for stimulus 0 with min spiking rate of 0.0
# Issues summary {'negative_di': 0, 'n_areas': 0, 'zero_contrib': 0, 'low_firing_rates': 0}
# Working with 0 units for stimulus 1 with min spiking rate of 0.0
# Issues summary {'negative_di': 0, 'n_areas': 0, 'zero_contrib': 0, 'low_firing_rates': 0}
# Working with 0 units for stimulus 1 with min spiking rate of 0.0
# Issues summary {'negative_di': 0, 'n_areas': 0, 'zero_contrib': 0, 'low_firing_rates': 0}
# Working with 0 units for stimulus 2 with min spiking rate of 0.0
# Issues summary {'negative_di': 0, 'n_areas': 0, 'zero_contrib': 0, 'low_firing_rates': 0}
# Working with 0 units for stimulus 2 with min spiking rate of 0.0
# Issues summary {'negative_di': 0, 'n_areas': 0, 'zero_contrib': 0, 'low_firing_rates': 0}
# ...

# %%
## reload and plot 
# data_9 = utils.read_pickle_file('/Users/yido/Code/neuroscience/output_stimuli_9/stimulus_9_500_1500_0.2_areal_plots_data.pkl')
# data_15 = utils.read_pickle_file('/Users/yido/Code/neuroscience/output_stimuli_15/stimulus_15_500_1500_0.2_areal_plots_data.pkl')

    
plot_all_area_based(data_15, '15', '/Users/yido/Code/neuroscience/output_stimuli_15/stimulus_15_500_1500_0.2_Dec_24_top25.pdf')
# plot_all_area_based(data_9, '9', '/Users/yido/Code/neuroscience/output_stimuli_9/stimulus_9_500_1500_0.2_Dec_24.pdf')
# Out:
# vmax 0.8532146432438334
# vmax nan
# vmax 0.24856644890211232
# vmax nan
# /var/folders/9z/rswwj73n50ngqsj_m1kp1hp00000gn/T/ipykernel_38461/3074402392.py:81: RuntimeWarning: All-NaN slice encountered
#   vmax = np.nanmax(np.abs(data))
# vmax 0.9445779077993277
# vmax 0.1887821157959576
# vmax 0.3102215493103576
# vmax 0.7442595610694525
# vmax 1.821774528909911
